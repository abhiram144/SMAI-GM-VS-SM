# %% [markdown]
# **This script demonstrates how to compute a graph edit distance.**
# ---

# %% [markdown]
# **0.   Install `graphkit-learn`.**

# %% [markdown]
# **1.   Get dataset.**

# %%
import networkx
import matplotlib.pyplot as plt
import numpy as np
from gklearn.utils import *

# %%
# Predefined dataset name, use dataset "MUTAG".
ds_name = 'AIDS'

# Initialize a Dataset.
dataset = Dataset()
# Load predefined dataset "MUTAG".
dataset.load_predefined_dataset(ds_name)
graph1 = dataset.graphs[0]
graph2 = dataset.graphs[1]
print(graph1, graph2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-2eee20bfaf7a> in <module>
#       6 dataset = Dataset()
#       7 # Load predefined dataset "MUTAG".
# ----> 8 dataset.load_predefined_dataset(ds_name)
#       9 graph1 = dataset.graphs[0]
#      10 graph2 = dataset.graphs[1]
#
# ~\.conda\envs\SMAI\lib\site-packages\gklearn\utils\dataset.py in load_predefined_dataset(self, ds_name)
#      74                 elif ds_name == 'AIDS':
#      75                         ds_file = current_path + '../../datasets/AIDS/AIDS_A.txt'
# ---> 76                         self.__graphs, self.__targets, label_names = load_dataset(ds_file)
#      77                 elif ds_name == 'Alkane':
#      78                         ds_file = current_path + '../../datasets/Alkane/dataset.ds'
#
# ~\.conda\envs\SMAI\lib\site-packages\gklearn\utils\graph_files.py in load_dataset(filename, filename_targets, gformat, **kwargs)
#      59                 data, y, label_names = load_mat(filename, order)
#      60         elif extension == 'txt':
# ---> 61                 data, y, label_names = load_tud(filename)
#      62
#      63         return data, y, label_names
#
# ~\.conda\envs\SMAI\lib\site-packages\gklearn\utils\graph_files.py in load_tud(filename)
#     530
#     531         # load data file names
# --> 532         for name in listdir(dirname_dataset):
#     533                 if ds_name + '_A' in name:
#     534                         fam = dirname_dataset + '/' + name
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\venka\\.conda\\envs\\SMAI\\lib\\site-packages\\gklearn\\utils/../../datasets/AIDS'

# %%
path = "E:\SMAI IIIT H\SMAI-GM-VS-SM\AIDS\AIDS\data"
node = graphfiles.loadGXL(path+r"\171.gxl")
# Out:
# molid3225

# %%
len(graph2)
# Out:
# 11

# %%
np.argmax([len(graph) for graph in dataset.graphs])
# Out:
# 453

# %%
G = networkx.petersen_graph()

# %%
# %matplotlib inline
networkx.draw(G)

# %%
plt.figure(figsize=[12, 7])
plt.subplot(121)
networkx.draw(graph1)
plt.subplot(122)
networkx.draw(graph2)

# %% [markdown]
# **2.  Compute graph edit distance.**

# %%
from gklearn.ged.env import GEDEnv


ged_env = GEDEnv() # initailize GED environment.
ged_env.set_edit_cost('CONSTANT', # GED cost type.
                      edit_cost_constants=[3, 3, 1, 3, 3, 1] # edit costs.
										 )  
ged_env.add_nx_graph(graph1, '') # add graph1
ged_env.add_nx_graph(graph2, '') # add graph2
listID = ged_env.get_all_graph_ids() # get list IDs of graphs
ged_env.init(init_type='LAZY_WITHOUT_SHUFFLED_COPIES') # initialize GED environment.
options = {'initialization_method': 'RANDOM', # or 'NODE', etc.
           'threads': 1 # parallel threads.
					}
ged_env.set_method('BIPARTITE', # GED method.
                   options # options for GED method.
									)
ged_env.init_method() # initialize GED method.

ged_env.run_method(listID[0], listID[1]) # run.

pi_forward = ged_env.get_forward_map(listID[0], listID[1]) # forward map.
pi_backward = ged_env.get_backward_map(listID[0], listID[1]) # backward map.
dis = ged_env.get_upper_bound(listID[0], listID[1])	# GED bewteen two graphs.
print(pi_forward)
print(pi_backward)
print(dis)
# Out:
# [9, 3, 1, inf, inf, 10, 0, 2, 8, 7, 6, inf, 4, 5, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf]
# [6, 2, 7, 1, 12, 13, 10, 9, 8, 0, 5]
# 305

# %% [markdown]
# Okay maastaru Nenu padkuntunna...
# Bye..
